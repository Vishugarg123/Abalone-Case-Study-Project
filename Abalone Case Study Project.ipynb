# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("https://raw.githubusercontent.com/dsrscientist/dataset1/master/abalone.csv")
df
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0      M   0.455     0.365   0.095        0.5140          0.2245
# 1      M   0.350     0.265   0.090        0.2255          0.0995
# 2      F   0.530     0.420   0.135        0.6770          0.2565
# 3      M   0.440     0.365   0.125        0.5160          0.2155
# 4      I   0.330     0.255   0.080        0.2050          0.0895
# ...   ..     ...       ...     ...           ...             ...
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# ...

# %%
df.isnull().sum()
# Out:
# Sex               0
# Length            0
# Diameter          0
# Height            0
# Whole weight      0
# Shucked weight    0
# Viscera weight    0
# Shell weight      0
# Rings             0
# dtype: int64

# %%
df['Sex'].value_counts()
# Out:
# M    1528
# I    1342
# F    1307
# Name: Sex, dtype: int64

# %%
df.describe
# Out:
# <bound method NDFrame.describe of      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0      M   0.455     0.365   0.095        0.5140          0.2245
# 1      M   0.350     0.265   0.090        0.2255          0.0995
# 2      F   0.530     0.420   0.135        0.6770          0.2565
# 3      M   0.440     0.365   0.125        0.5160          0.2155
# 4      I   0.330     0.255   0.080        0.2050          0.0895
# ...   ..     ...       ...     ...           ...             ...
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# ...

# %%
df.corr()
# Out:
#                   Length  Diameter    Height  Whole weight  Shucked weight  \
# Length          1.000000  0.986812  0.827554      0.925261        0.897914
# Diameter        0.986812  1.000000  0.833684      0.925452        0.893162
# Height          0.827554  0.833684  1.000000      0.819221        0.774972
# Whole weight    0.925261  0.925452  0.819221      1.000000        0.969405
# Shucked weight  0.897914  0.893162  0.774972      0.969405        1.000000
# Viscera weight  0.903018  0.899724  0.798319      0.966375        0.931961
# Shell weight    0.897706  0.905330  0.817338      0.955355        0.882617
# Rings           0.556720  0.574660  0.557467      0.540390        0.420884
#
#                 Viscera weight  Shell weight     Rings
# Length                0.903018      0.897706  0.556720
# Diameter              0.899724      0.905330  0.574660
# Height                0.798319      0.817338  0.557467
# Whole weight          0.966375      0.955355  0.540390
# ...

# %%
plt.figure(figsize=(15,8))
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4177 entries, 0 to 4176
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Sex             4177 non-null   object
#  1   Length          4177 non-null   float64
#  2   Diameter        4177 non-null   float64
#  3   Height          4177 non-null   float64
#  4   Whole weight    4177 non-null   float64
#  5   Shucked weight  4177 non-null   float64
#  6   Viscera weight  4177 non-null   float64
#  7   Shell weight    4177 non-null   float64
#  8   Rings           4177 non-null   int64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 293.8+ KB

# %%
sns.pairplot(df)

# %%
df.columns
# Out:
# Index(['Sex', 'Length', 'Diameter', 'Height', 'Whole weight', 'Shucked weight',
#        'Viscera weight', 'Shell weight', 'Rings'],
#       dtype='object')

# %%
sns.scatterplot(x='Length',y='Rings',data=df)
plt.show()

# %%
sns.scatterplot(x='Diameter',y='Rings',data=df)
plt.show()

# %%
sns.scatterplot(x='Height',y='Rings',data=df)
plt.show()

# %%
sns.scatterplot(x='Whole weight',y='Rings',data=df)
plt.show()

# %%
sns.scatterplot(x='Viscera weight',y='Rings',data=df)
plt.show()

# %%
df.corr()['Rings'].sort_values()
# Out:
# Shucked weight    0.420884
# Viscera weight    0.503819
# Whole weight      0.540390
# Length            0.556720
# Height            0.557467
# Diameter          0.574660
# Shell weight      0.627574
# Rings             1.000000
# Name: Rings, dtype: float64

# %%
plt.figure(figsize=(18,8))
sns.boxplot(df['Rings'],df['Length'],hue=df['Sex'],palette = 'pastel')
plt.title("Rings vs Length")
plt.show()

# %%
plt.figure(figsize=(18,8))
sns.boxplot(df['Rings'],df['Diameter'],hue=df['Sex'],palette = 'pastel')
plt.title("Rings vs Diameter")
plt.show()

# %%
plt.figure(figsize=(18,8))
sns.violinplot(df['Rings'],df['Whole weight'],hue=df['Sex'],palette = 'pastel')
plt.title("Rings vs Whole weight")
plt.show()

# %%
plt.figure(figsize=(18,8))
sns.boxenplot(df['Rings'],df['Height'],hue=df['Sex'],palette = 'pastel')
plt.title("Rings vs Height")
plt.show()

# %%
plt.figure(figsize=(18,8))
sns.swarmplot(df['Rings'],df['Shucked weight'],hue=df['Sex'],palette = 'pastel')
plt.title("Rings vs Shucked weight")
plt.show()

# %%
plt.figure(figsize=(18,8))
sns.stripplot(df['Rings'],df['Viscera weight'],hue=df['Sex'],palette = 'pastel')
plt.title("Rings vs Viscera weight")
plt.show()

# %%
plt.figure(figsize=(18,8))
sns.stripplot(df['Rings'],df['Shell weight'],hue=df['Sex'],palette = 'pastel')
plt.title("Rings vs Shell weigh")
plt.show()

# %%
df.plot(kind='density',subplots=True,layout=(6,11),sharex=False,legend=False,fontsize=1,figsize=(18,12))
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df['Sex']=le.fit_transform(df['Sex'])
df['Sex'].value_counts()
# Out:
# 2    1528
# 1    1342
# 0    1307
# Name: Sex, dtype: int64

# %%
df.Sex=df.Sex.astype(float)

# %%
def label_race (row):
   if row['Rings']>=1 and row['Rings']<=8:
      return 1
   elif row['Rings'] >=9 and row['Rings']<=10:
      return 2
   elif row['Rings']>=11 and row['Rings']<=29:
      return 3
   return 0

# %%
df['Age'] = df.apply(lambda _: '', axis=1)

# %%
df['Age']=df.apply (lambda row: label_race (row),axis=1)

# %%
df.head()
# Out:
#    Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0  2.0   0.455     0.365   0.095        0.5140          0.2245
# 1  2.0   0.350     0.265   0.090        0.2255          0.0995
# 2  0.0   0.530     0.420   0.135        0.6770          0.2565
# 3  2.0   0.440     0.365   0.125        0.5160          0.2155
# 4  1.0   0.330     0.255   0.080        0.2050          0.0895
#
#    Viscera weight  Shell weight  Rings  Age
# 0          0.1010         0.150     15    3
# 1          0.0485         0.070      7    1
# 2          0.1415         0.210      9    2
# 3          0.1140         0.155     10    2
# 4          0.0395         0.055      7    1

# %%
df[df['Height'] == 0]
# Out:
#       Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 1257  1.0   0.430      0.34     0.0         0.428          0.2065
# 3996  1.0   0.315      0.23     0.0         0.134          0.0575
#
#       Viscera weight  Shell weight  Rings  Age
# 1257          0.0860        0.1150      8    1
# 3996          0.0285        0.3505      6    1

# %%
from scipy.stats import zscore
z=np.abs(zscore(df))
z.shape
# Out:
# (4177, 10)

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([   6,   72,   81,   83,  129,  163,  164,  165,  165,  165,  166,
#         166,  167,  168,  170,  181,  232,  236,  236,  236,  237,  237,
#         238,  238,  239,  270,  275,  277,  278,  294,  310,  313,  314,
#         334,  351,  355,  358,  358,  362,  375,  416,  417,  428,  431,
#         433,  469,  478,  480,  501,  526,  526,  530,  572,  628,  673,
#         674,  675,  678,  694,  696,  696,  719,  719,  720,  720,  744,
#         754,  756,  811,  891,  891,  891, 1048, 1051, 1051, 1052, 1193,
#        1197, 1199, 1202, 1204, 1206, 1206, 1207, 1207, 1207, 1207, 1209,
#        1209, 1257, 1417, 1417, 1418, 1422, 1426, 1427, 1427, 1427, 1428,
#        1429, 1429, 1528, 1754, 1756, 1757, 1759, 1761, 1762, 1762, 1762,
#        1763, 1763, 1763, 1821, 1982, 1986, 1987, 1987, 2051, 2090, 2108,
#        2108, 2114, 2114, 2157, 2161, 2176, 2180, 2199, 2201, 2208, 2209,
#        2274, 2275, 2305, 2334, 2334, 2334, 2335, 2344, 2358, 2368, 2381,
# ...

# %%
len(np.where(z>3)[0])
# Out:
# 200

# %%
df_new=df[(z<3).all(axis=1)]
print("old dataframe",df.shape)
print("new dataframe",df_new.shape)
print('total_droped_rows',df.shape[0] - df_new.shape[0])
# Out:
# old dataframe (4177, 10)
# new dataframe (4027, 10)
# total_droped_rows 150

# %%
loss_percentage=(150/4177)*100
loss_percentage
# Out:
# 3.5910940866650707

# %%
y=df_new['Age']
x=df_new.drop(['Rings','Age'],axis=1)

# %%
y.shape
# Out:
# (4027,)

# %%
x.shape
# Out:
# (4027, 8)

# %%
from sklearn.preprocessing import power_transform
x=power_transform(x,method='yeo-johnson')

# %%
x
# Out:
# array([[ 1.13432919, -0.68445079, -0.54337947, ..., -0.54086524,
#         -0.68803217, -0.58635376],
#        [ 1.13432919, -1.4117394 , -1.40113174, ..., -1.31131805,
#         -1.33285416, -1.33271691],
#        [-1.31306782, -0.0462191 ,  0.03716259, ..., -0.36270513,
#         -0.24037305, -0.08021413],
#        ...,
#        [ 1.13432919,  0.65112915,  0.70592133, ...,  0.90189694,
#          1.08965131,  0.66363183],
#        [-1.31306782,  0.92606411,  0.8377131 , ...,  0.92415296,
#          0.87642835,  0.57752029],
#        [ 1.13432919,  1.9719402 ,  1.85550496, ...,  2.31446634,
#          1.73214622,  1.85675543]])

# %%
pd.DataFrame(x).skew()
# Out:
# 0   -0.174523
# 1   -0.082985
# 2   -0.080956
# 3   -0.015962
# 4   -0.016797
# 5    0.021815
# 6    0.035902
# 7    0.016660
# dtype: float64

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=sc.fit_transform(x)
x
# Out:
# array([[ 1.13432919, -0.68445079, -0.54337947, ..., -0.54086524,
#         -0.68803217, -0.58635376],
#        [ 1.13432919, -1.4117394 , -1.40113174, ..., -1.31131805,
#         -1.33285416, -1.33271691],
#        [-1.31306782, -0.0462191 ,  0.03716259, ..., -0.36270513,
#         -0.24037305, -0.08021413],
#        ...,
#        [ 1.13432919,  0.65112915,  0.70592133, ...,  0.90189694,
#          1.08965131,  0.66363183],
#        [-1.31306782,  0.92606411,  0.8377131 , ...,  0.92415296,
#          0.87642835,  0.57752029],
#        [ 1.13432919,  1.9719402 ,  1.85550496, ...,  2.31446634,
#          1.73214622,  1.85675543]])

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=0,test_size=0.20)
print("Shape of x_train :", x_train.shape)
print("Shape of x_test :", x_test.shape)
print("Shape of y_train :", y_train.shape)
print("Shape of y_test :", y_test.shape)
# Out:
# Shape of x_train : (3221, 8)
# Shape of x_test : (806, 8)
# Shape of y_train : (3221,)
# Shape of y_test : (806,)

# %%
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression()
from sklearn.metrics import accuracy_score

# %%
lr.fit(x_train,y_train)
pred_test=lr.predict(x_test)
print(accuracy_score(y_test,pred_test)*100)
print(confusion_matrix(y_test,pred_test))
print(classification_report(y_test,pred_test))
# Out:
# 65.50868486352357
# [[216  43  13]
#  [ 60 130  68]
#  [ 24  70 182]]
#               precision    recall  f1-score   support
#
#            1       0.72      0.79      0.76       272
#            2       0.53      0.50      0.52       258
#            3       0.69      0.66      0.68       276
#
#     accuracy                           0.66       806
#    macro avg       0.65      0.65      0.65       806
# weighted avg       0.65      0.66      0.65       806

# %% [markdown]
# # KNN Classifier

# %%
from sklearn.neighbors import KNeighborsClassifier
model=KNeighborsClassifier()
model.fit(x_train,y_train)
pred_test=model.predict(x_test)
print(accuracy_score(y_test,pred_test))
print(confusion_matrix(y_test,pred_test))
print(classification_report(y_test,pred_test))
# Out:
# 0.56575682382134
# [[198  58  16]
#  [ 65 110  83]
#  [ 31  97 148]]
#               precision    recall  f1-score   support
#
#            1       0.67      0.73      0.70       272
#            2       0.42      0.43      0.42       258
#            3       0.60      0.54      0.57       276
#
#     accuracy                           0.57       806
#    macro avg       0.56      0.56      0.56       806
# weighted avg       0.57      0.57      0.56       806

# %% [markdown]
# # SVC

# %%
from sklearn.svm import SVC
model=SVC()
model.fit(x_train,y_train)
y_pred=model.predict(x_test)
from sklearn.metrics import accuracy_score
print('accuracy_score:', accuracy_score(y_test,y_pred))
print(confusion_matrix(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# accuracy_score: 0.6513647642679901
# [[212  45  15]
#  [ 54 125  79]
#  [ 18  70 188]]
#               precision    recall  f1-score   support
#
#            1       0.75      0.78      0.76       272
#            2       0.52      0.48      0.50       258
#            3       0.67      0.68      0.67       276
#
#     accuracy                           0.65       806
#    macro avg       0.64      0.65      0.65       806
# weighted avg       0.65      0.65      0.65       806

# %%
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier(criterion='entropy',random_state=7)
model.fit(x_train,y_train)
y_pred=model.predict(x_test)
print('accuracy_score:', accuracy_score(y_test,y_pred))
print(confusion_matrix(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# accuracy_score: 0.5719602977667494
# [[182  59  31]
#  [ 54 127  77]
#  [ 32  92 152]]
#               precision    recall  f1-score   support
#
#            1       0.68      0.67      0.67       272
#            2       0.46      0.49      0.47       258
#            3       0.58      0.55      0.57       276
#
#     accuracy                           0.57       806
#    macro avg       0.57      0.57      0.57       806
# weighted avg       0.58      0.57      0.57       806

# %%
from sklearn.naive_bayes import GaussianNB
model=GaussianNB()
model.fit(x_train,y_train)
y_pred=model.predict(x_test)
print('accuracy_score:',accuracy_score(y_test,y_pred))
print(confusion_matrix(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# accuracy_score: 0.5719602977667494
# [[212  42  18]
#  [ 61  94 103]
#  [ 39  82 155]]
#               precision    recall  f1-score   support
#
#            1       0.68      0.78      0.73       272
#            2       0.43      0.36      0.39       258
#            3       0.56      0.56      0.56       276
#
#     accuracy                           0.57       806
#    macro avg       0.56      0.57      0.56       806
# weighted avg       0.56      0.57      0.56       806

# %%
from sklearn.ensemble import RandomForestClassifier
model=RandomForestClassifier(random_state=1)
model.fit(x_train,y_train)
y_pred=model.predict(x_test)
print('accuracy_score:',accuracy_score(y_test,y_pred))
print(confusion_matrix(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# accuracy_score: 0.6277915632754343
# [[206  48  18]
#  [ 51 126  81]
#  [ 15  87 174]]
#               precision    recall  f1-score   support
#
#            1       0.76      0.76      0.76       272
#            2       0.48      0.49      0.49       258
#            3       0.64      0.63      0.63       276
#
#     accuracy                           0.63       806
#    macro avg       0.63      0.63      0.63       806
# weighted avg       0.63      0.63      0.63       806

# %% [markdown]
# # Hyper parameter tuning

# %%
LogisticRegression()
# Out:
# LogisticRegression()

# %%
from sklearn.model_selection import GridSearchCV
grid={"C":np.logspace(-3,3,7), "penalty":["l1","l2"]}

# %%
GSCV=GridSearchCV(LogisticRegression(),grid,cv=10)
GSCV.fit(x_train,y_train)
GSCV.best_params_
# Out:
# {'C': 1.0, 'penalty': 'l2'}

# %%
GSCV_pred=GSCV.best_estimator_.predict(x_test)
print("best score:",accuracy_score(y_test,GSCV_pred))
# Out:
# best score: 0.6550868486352357

# %%
from sklearn.metrics import plot_roc_curve
plot_roc_curve(GSCV.best_estimator_,x_test,y_test)
plt.title("ROC AUC Curve")
plt.show()

# %%
import joblib
joblib.dump(GSCV.best_estimator_,"Abalone model.pkl")
